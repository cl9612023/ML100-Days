# %% [markdown]
# 作業1：Hourly Energy Consumption
# (1)它針對美國東部電力傳輸做觀察
# (2)它是跟據官方所提供的每小時耗電去做評估的
# (3)它所收集到的資訊以數字資訊轉乘表格資訊
# (4)利用預測的能耗來跟實際做比較

# %% [markdown]
# 作業2：想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# (1)提升載客量和使用用戶
# (2)利用app或網頁收客戶意見，和改善目標，如果沒有則利用街頭收集資料
# (3)可能是文字意見或表格
# (4)利用數學的方式去做分析確認

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
#載入需要的library
import numpy as np
import matplotlib.pyplot as plt

# %%
#y ==>預測值(矩陣)，y_hat ==>實際值(標準)(矩陣)
#mse(mean_squared_error)
def mean_squared_error(y, y_hat):
    MSE= sum((y-y_hat)**2)/len(y)
    return MSE

#mae(mean_absolute_error)
def mean_absolute_error(y, y_hat):
    MAE = sum(abs(y - y_hat)) / len(y)
    return MAE

# %%
#產生誤差數值
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)#產生x軸(input)[0到100切101份]

#np.random.randn(101)產生隨機亂數(正態分佈)
y = (x_lin + np.random.randn(101) * 5) * w + b #y軸(output)

#畫圖
plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)#圖例位置
plt.show()

# %%
#產生表準數值
y_hat = x_lin * w + b #沒有加亂數
plt.plot(x_lin, y, 'b.', label = 'data')#'b.'藍點
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')#'r-'紅線
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行，計算兩種誤差表示
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 279.141
# The Mean absolute error is 13.074
